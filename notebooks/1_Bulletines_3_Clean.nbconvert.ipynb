# %% [markdown]
# ## Bulletines Cleaning
#
# I used this notebook to clean raw data previously scraped containing information from the monthly bulletines published by the Italian Ministry of Justice.

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Basic cleaning
#
# - Converting numbers into integers (note that the `.` in Italy is being used as a decimal separator)
# - Removing `Totals` (we'll calculate them when needed)
# - Fixing empty values to numeric (from NaN to 0)
# - Converting to integer

# %%
# Read CSV with thousands separator specified
df = pd.read_csv("../outputs/raw/bulletines_raw.csv", thousands=".")

# Remove rows where "Regione di detenzione" is "Totale"
df = df[df["Regione di detenzione"] != "Totale"]

# Replace empty strings and similar with NaN
df.replace(["", " ", "NaN", "nan"], np.nan, inplace=True)

# Fill NaN values with 0
df.fillna(0, inplace=True)

# Convert columns to integer type
df['Detenuti presenti - stranieri'] = df['Detenuti presenti - stranieri'].astype(int)

# Remove dots from numeric strings in the specified column
df['Detenuti presenti - totale'] = df['Detenuti presenti - totale'].str.replace(".", "")

# Show a random sample of 5 rows
df.sample(5)
# Out:
#      Regione di detenzione Sigla Provincia  \
# 1736              CAMPANIA              AV
# 4527               TOSCANA              AR
# 7737               SICILIA              CL
# 1842              SARDEGNA              SS
# 2933             LOMBARDIA              MI
#
#                                                Istituto Tipo istituto  \
# 1736  SANT'ANGELO DEI LOMBARDI "L.FAMIGLIETTI - R.FO...            CR
# 4527                                           AREZZO -            CC
# 7737                                               GELA            CC
# 1842                             SASSARI "G. BACCHIDDU"            CC
# 2933                                     OPERA "I C.R."            CR
#
#       Capienza Regolamentare Detenuti presenti - totale  \
# 1736                     124                        180
# 4527                     104                         31
# 7737                      48                         66
# 1842                     454                        465
# 2933                     918                       1322
#
#      Detenuti presenti - donne  Detenuti presenti - stranieri  \
# 1736                         0                             18
# 4527                         0                             16
# 7737                         0                              9
# 1842                        15                            117
# 2933                         0                            364
#
#      Ultimo aggiornamento         ID
# 1736           2023-11-30  SST449508
# 4527           2022-09-30  SST398014
# 7737           2021-04-30  SST331096
# 1842           2023-11-30  SST449508
# 2933           2023-05-31  SST431165

# %%
df.dtypes
# Out:
# Regione di detenzione            object
# Sigla Provincia                  object
# Istituto                         object
# Tipo istituto                    object
# Capienza Regolamentare            int64
# Detenuti presenti - totale       object
# Detenuti presenti - donne        object
# Detenuti presenti - stranieri     int64
# Ultimo aggiornamento             object
# ID                               object
# dtype: object

# %%
# Step 1: Replace dots in the 'Detenuti presenti - totale' column, then convert to numeric
df['Detenuti presenti - totale'] = df['Detenuti presenti - totale'].str.replace(".", "").astype(float)
# Step 2: Fill any remaining NaN values with 0
df['Detenuti presenti - totale'].fillna(0, inplace=True)
# Step 3: Convert the cleaned column to integers
df['Detenuti presenti - totale'] = df['Detenuti presenti - totale'].astype(int)
df['Detenuti presenti - donne'] = df['Detenuti presenti - donne'].astype(int)
# Out:
# /tmp/ipykernel_3324/1983749719.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Detenuti presenti - totale'].fillna(0, inplace=True)

# %%
df.sort_values('Detenuti presenti - stranieri', ascending=False).head(15)
# Out:
#       Regione di detenzione Sigla Provincia  \
# 13197             LOMBARDIA              MI
# 2010               PIEMONTE              TO
# 1221              LOMBARDIA              MI
# 1630               PIEMONTE              TO
# 1820               PIEMONTE              TO
# 651               LOMBARDIA              MI
# 1411              LOMBARDIA              MI
# 300                PIEMONTE              TO
# 1440               PIEMONTE              TO
# 841               LOMBARDIA              MI
# 11510              PIEMONTE              TO
# 490                PIEMONTE              TO
# 13036              PIEMONTE              TO
# 271               LOMBARDIA              MI
# 110                PIEMONTE              TO
#
#                                            Istituto Tipo istituto  \
# 13197            MILANO "F. DI CATALDO" SAN VITTORE            CC
# 2010   TORINO "G. LORUSSO - L. CUTUGNO" LE VALLETTE            CC
# 1221             MILANO "F. DI CATALDO" SAN VITTORE            CC
# 1630   TORINO "G. LORUSSO - L. CUTUGNO" LE VALLETTE            CC
# 1820   TORINO "G. LORUSSO - L. CUTUGNO" LE VALLETTE            CC
# 651              MILANO "F. DI CATALDO" SAN VITTORE            CC
# 1411             MILANO "F. DI CATALDO" SAN VITTORE            CC
# 300    TORINO "G. LORUSSO - L. CUTUGNO" LE VALLETTE            CC
# 1440   TORINO "G. LORUSSO - L. CUTUGNO" LE VALLETTE            CC
# 841              MILANO "F. DI CATALDO" SAN VITTORE            CC
# 11510    TORINO "G. LORUSSO L. CUTUGNO" LE VALLETTE            CC
# 490    TORINO "G. LORUSSO - L. CUTUGNO" LE VALLETTE            CC
# 13036    TORINO "G. LORUSSO L. CUTUGNO" LE VALLETTE            CC
# 271              MILANO "F. DI CATALDO" SAN VITTORE            CC
# 110    TORINO "G. LORUSSO - L. CUTUGNO" LE VALLETTE            CC
#
#        Capienza Regolamentare  Detenuti presenti - totale  \
# 13197                     748                        1149
# 2010                     1118                        1496
# 1221                      754                        1146
# 1630                     1118                        1491
# 1820                     1118                        1480
# 651                       754                        1150
# 1411                      754                        1158
# 300                      1117                        1494
# 1440                     1118                        1444
# 841                       754                        1126
# 11510                    1061                        1516
# 490                      1117                        1478
# 13036                    1117                        1471
# 271                       749                        1111
# 110                      1117                        1473
#
#        Detenuti presenti - donne  Detenuti presenti - stranieri  \
# 13197                         83                            732
# 2010                         126                            719
# 1221                          85                            716
# 1630                         126                            714
# 1820                         125                            714
# 651                           85                            709
# 1411                          81                            708
# 300                          135                            706
# 1440                         128                            698
# 841                           82                            695
# 11510                        144                            694
# 490                          131                            694
# 13036                        123                            692
# 271                           83                            691
# 110                          128                            689
#
#       Ultimo aggiornamento          ID
# 13197           2024-10-31  SST1428284
# 2010            2023-10-31   SST447996
# 1221            2024-02-29   SST462936
# 1630            2023-12-31   SST454090
# 1820            2023-11-30   SST449508
# 651             2024-05-31  SST1407300
# 1411            2024-01-31   SST459023
# 300             2024-07-31  SST1415275
# 1440            2024-01-31   SST459023
# 841             2024-04-30  SST1402560
# 11510           2019-08-31   SST212437
# 490             2024-06-30  SST1410601
# 13036           2024-09-30  SST1424720
# 271             2024-07-31  SST1415275
# 110             2024-08-31  SST1418233

# %%
df.dtypes
# Out:
# Regione di detenzione            object
# Sigla Provincia                  object
# Istituto                         object
# Tipo istituto                    object
# Capienza Regolamentare            int64
# Detenuti presenti - totale        int64
# Detenuti presenti - donne         int64
# Detenuti presenti - stranieri     int64
# Ultimo aggiornamento             object
# ID                               object
# dtype: object

# %%
# Convert the 'Ultimo aggiornamento' column to datetime format
df['Ultimo aggiornamento'] = pd.to_datetime(df['Ultimo aggiornamento'])

# %%
df.dtypes
# Out:
# Regione di detenzione                    object
# Sigla Provincia                          object
# Istituto                                 object
# Tipo istituto                            object
# Capienza Regolamentare                    int64
# Detenuti presenti - totale                int64
# Detenuti presenti - donne                 int64
# Detenuti presenti - stranieri             int64
# Ultimo aggiornamento             datetime64[ns]
# ID                                       object
# dtype: object

# %% [markdown]
# ### Fixing names
#
# A problem we are encountering are the many different names each detention center has been registered with over the years. Here below we use [thefuzz](https://github.com/seatgeek/thefuzz) to do an initial fuzzy matching, and then fix the remaining ones manually. As a reference, we'll use the information we have scraped in a different notebook about all the detention centers currently operating in Italy.

# %%
df['Istituto'] = df['Istituto'].str.strip()
df['Istituto'] = df['Istituto'].str.replace(r"\s*-", "", regex=True)  # Removes any whitespace followed by a dash

# %%
sorted(df['Istituto'].unique())
# Out:
# ['AGRIGENTO "P. DI LORENZO"',
#  'AGRIGENTO "PASQUALE DI LORENZO"',
#  'ALBA "G. MONTALTO"',
#  'ALBA "GIUSEPPE MONTALTO"',
#  'ALESSANDRIA "G. CANTIELLO  S. GAETA"',
#  'ALESSANDRIA "G. CANTIELLO S. GAETA"',
#  'ALESSANDRIA "SAN MICHELE"',
#  'ALGHERO "G. TOMASIELLO"',
#  'ALGHERO "GIUSEPPE TOMASIELLO"',
#  'ALTAMURA',
#  'ANCONA',
#  'ANCONA "BARCAGLIONE"',
#  'ARBUS "IS ARENAS"',
#  'AREZZO',
#  'ARIANO IRPINO "P. CAMPANELLO"',
#  'ARIANO IRPINO "PASQUALE CAMPANELLO"',
#  'ARIENZO',
#  'ARIENZO "G. DE ANGELIS"',
#  'ARIENZO "GENNARO DE ANGELIS"',
#  'ASCOLI PICENO',
#  'ASTI',
#  'AUGUSTA',
#  'AVELLINO "A. GRAZIANO" BELLIZZI',
#  'AVELLINO "ANTIMO GRAZIANO" BELLIZZI',
#  'AVERSA "F. SAPORITO"',
#  'AVEZZANO',
#  'BARCELLONA POZZO DI GOTTO',
#  'BARI "F. RUCCI"',
#  'BARI "FRANCESCO RUCCI"',
#  'BELLUNO',
#  'BENEVENTO',
#  'BENEVENTO "M. GAGLIONE"',
#  'BERGAMO',
#  'BERGAMO "Don Fausto RESMINI"',
#  'BIELLA',
#  'BOLLATE "II C.R."',
#  'BOLOGNA "R. D\'AMATO"',
#  'BOLOGNA "ROCCO D\'AMATO"',
#  'BOLZANO',
#  'BRESCIA "N. FISCHIONE" CANTON MONBELLO',
#  'BRESCIA "NERIO FISCHIONE" CANTON MONBELLO',
#  'BRESCIA "VERZIANO"',
#  'BRINDISI',
#  'BRISSOGNE "AOSTA"',
#  'BUSTO ARSIZIO',
#  'CAGLIARI "E.SCALAS"',
#  'CAGLIARI "ETTORE SCALAS"',
#  'CALTAGIRONE',
#  'CALTANISSETTA',
#  'CAMERINO',
#  'CAMPOBASSO',
#  'CARINOLA "G.B. NOVELLI"',
#  'CASSINO',
#  'CASTELFRANCO EMILIA',
#  'CASTELVETRANO',
#  'CASTROVILLARI "R. SISCA"',
#  'CASTROVILLARI "ROSA SISCA"',
#  'CATANIA "BICOCCA"',
#  'CATANIA "PIAZZA LANZA"',
#  'CATANZARO "U. CARIDI"',
#  'CATANZARO "UGO CARIDI"',
#  'CHIAVARI',
#  'CHIETI',
#  'CIVITAVECCHIA "G. PASSERINI"',
#  'CIVITAVECCHIA "GIUSEPPE PASSERINI"',
#  'CIVITAVECCHIA "N.C."',
#  'COMO',
#  'COSENZA "S. COSMAI"',
#  'COSENZA "SERGIO COSMAI"',
#  'CREMONA',
#  'CROTONE',
#  'CUNEO',
#  'EBOLI',
#  'ENNA "L. BODENZA"',
#  'ENNA "LUIGI BODENZA"',
#  'FAVIGNANA "G. BARRACO"',
#  'FAVIGNANA "GIUSEPPE BARRACO"',
#  'FERMO',
#  'FERRARA "C. SATTA"',
#  'FERRARA "COSTANTINO SATTA"',
#  'FIRENZE "MARIO GOZZINI"',
#  'FIRENZE "SOLLICCIANO"',
#  'FOGGIA',
#  "FORLI'",
#  'FOSSANO',
#  'FOSSOMBRONE',
#  'FROSINONE "G. PAGLIEI"',
#  'FROSINONE "GIUSEPPE PAGLIEI"',
#  'GELA',
#  'GENOVA "MARASSI"',
#  'GENOVA "PONTEDECIMO"',
#  'GIARRE',
#  'GORIZIA',
#  'GROSSETO',
#  'IMPERIA',
#  'ISERNIA',
#  'ISILI',
#  'IVREA',
#  "L'AQUILA",
#  'LA SPEZIA',
#  'LANCIANO',
#  'LANUSEI "SAN DANIELE"',
#  'LARINO',
#  'LATINA',
#  'LAUREANA DI BORRELLO "L. DAGA"',
#  'LAURO',
#  'LECCE "N.C."',
#  'LECCO',
#  'LIVORNO',
#  'LIVORNO "GORGONA"',
#  'LOCRI',
#  'LODI',
#  'LUCCA',
#  'LUCERA',
#  'MANTOVA',
#  'MASSA',
#  'MASSA MARITTIMA',
#  'MATERA',
#  'MELFI',
#  'MESSINA',
#  'MILANO "F. DI CATALDO" SAN VITTORE',
#  'MILANO "FRANCESCO DI CATALDO" SAN VITTORE',
#  'MODENA',
#  'MONZA',
#  'NAPOLI "G. SALVIA" POGGIOREALE',
#  'NAPOLI "GIUSEPPE SALVIA" POGGIOREALE',
#  'NAPOLI "P. MANDATO" SECONDIGLIANO',
#  'NAPOLI "PASQUALE MANDATO" SECONDIGLIANO',
#  'NOTO "A. BONINCONTRO"',
#  'NOTO "ATTILIO BONINCONTRO"',
#  'NOVARA',
#  'NUORO',
#  'ONANI "MAMONE"',
#  'OPERA "I C.R."',
#  'ORISTANO "S. SORO"',
#  'ORISTANO "SALVATORE SORO"',
#  'ORVIETO',
#  'PADOVA',
#  'PADOVA "N.C."',
#  'PALERMO "A. LORUSSO" PAGLIARELLI',
#  'PALERMO "ANTONIO LORUSSO" PAGLIARELLI',
#  'PALERMO "C. DI BONA" UCCIARDONE',
#  'PALERMO "CALOGERO DI BONA" UCCIARDONE',
#  'PALIANO',
#  'PALMI "F. SALSONE"',
#  'PALMI "FILIPPO SALSONE"',
#  'PAOLA',
#  'PARMA',
#  'PAVIA',
#  'PERUGIA "NUOVO COMPLESSO PENITENZIARIO CAPANNE"',
#  'PESARO',
#  'PESCARA',
#  'PIACENZA "SAN LAZZARO"',
#  'PIAZZA ARMERINA',
#  'PISA',
#  'PISTOIA',
#  'PORDENONE',
#  'PORTO AZZURRO "P. DE SANTIS"',
#  'PORTO AZZURRO "PASQUALE DE SANTIS"',
#  'POTENZA "A. SANTORO"',
#  'POTENZA "ANTONIO SANTORO"',
#  'POZZUOLI',
#  'PRATO',
#  'RAGUSA',
#  'RAVENNA',
#  'REGGIO CALABRIA "ARGHILLA\'"',
#  'REGGIO CALABRIA "G. PANZERA"',
#  'REGGIO CALABRIA "GIUSEPPE PANZERA"',
#  'REGGIO EMILIA "C.C.  E   C.R."',
#  'REGGIO EMILIA "C.C. E C.R."',
#  'RIETI "N.C."',
#  'RIMINI',
#  'ROMA "G. STEFANINI" REBIBBIA FEMMINILE',
#  'ROMA "GERMANA STEFANINI" REBIBBIA FEMMINILE',
#  'ROMA "R. CINOTTI" REBIBBIA N.C.1',
#  'ROMA "RAFFAELE CINOTTI" REBIBBIA N.C.1',
#  'ROMA "REBIBBIA TERZA CASA"',
#  'ROMA "REBIBBIA"',
#  'ROMA "REGINA COELI"',
#  'ROSSANO "N.C."',
#  'ROVIGO',
#  'SALERNO "A. CAPUTO"',
#  'SALERNO "ANTONIO CAPUTO"',
#  'SALUZZO "R. MORANDI"',
#  'SALUZZO "RODOLFO MORANDI"',
#  'SAN CATALDO',
#  'SAN GIMIGNANO',
#  'SAN REMO "N.C."',
#  'SAN SEVERO',
#  'SANREMO',
#  'SANT\'ANGELO DEI LOMBARDI "L.FAMIGLIETTI  R.FORGETTA  G.BARTOLO"',
#  'SANT\'ANGELO DEI LOMBARDI "L.FAMIGLIETTI R.FORGETTA G.BARTOLO"',
#  'SANTA MARIA CAPUA VETERE "F. UCCELLA"',
#  'SASSARI "G. BACCHIDDU"',
#  'SASSARI "GIOVANNI BACCHIDDU"',
#  'SCIACCA',
#  'SIENA',
#  'SIRACUSA',
#  'SONDRIO',
#  'SPOLETO',
#  'SULMONA',
#  'TARANTO',
#  'TEMPIO PAUSANIA "P. PITTALIS"',
#  'TEMPIO PAUSANIA "PAOLO PITTALIS"',
#  'TERAMO',
#  'TERMINI IMERESE "A. BURRAFATO"',
#  'TERMINI IMERESE "ANTONINO BURRAFATO"',
#  'TERNI',
#  'TOLMEZZO',
#  'TORINO "G. LORUSSO  L. CUTUGNO" LE VALLETTE',
#  'TORINO "G. LORUSSO L. CUTUGNO" LE VALLETTE',
#  'TRANI',
#  'TRAPANI "P. CERULLI"',
#  'TRAPANI "PIETRO CERULLI"',
#  'TRENTO "SPINI DI GARDOLO"',
#  'TREVISO',
#  'TRIESTE',
#  'TURI',
#  'UDINE',
#  'VALLO DELLA LUCANIA',
#  'VALLO DELLA LUCANIA "A. PARAGANO"',
#  'VARESE',
#  'VASTO',
#  'VELLETRI',
#  'VENEZIA "GIUDECCA"',
#  'VENEZIA "SANTA MARIA MAGGIORE"',
#  'VERBANIA',
#  'VERCELLI',
#  'VERONA "MONTORIO"',
#  'VIBO VALENTIA "N.C."',
#  'VICENZA',
#  'VIGEVANO',
#  'VITERBO "N. IZZO"',
#  'VITERBO "N.C."',
#  'VOGHERA "N.C."',
#  'VOLTERRA']

# %%
from thefuzz import process

# %%
# Import standard names
df_standard_names = pd.read_csv('../outputs/clean/institutes_info.csv')
standard_names = df_standard_names['nome_istituto'].tolist()
standard_names
# Out:
# ['Reggio Calabria Arghillà',
#  'Brescia Verziano',
#  'Busto Arsizio',
#  'Como',
#  'Cremona',
#  'Lecco',
#  'Lodi',
#  'Mantova',
#  'Monza',
#  'Pavia',
#  'Sondrio',
#  'Varese',
#  'Voghera',
#  'Catanzaro',
#  'Crotone',
#  'Palmi',
#  'Paola',
#  'Rossano',
#  'Vibo Valentia',
#  'Ariano Irpino',
#  'Aversa',
#  'Carinola',
#  'Eboli',
#  'Bolzano',
#  'Gorizia',
#  'Padova',
#  'Santa Maria Capua Vetere',
#  'Pordenone',
#  'Rovigo',
#  'Ascoli Piceno',
#  'Castelfranco Emilia',
#  'Fermo',
#  'Treviso',
#  'Fossombrone',
#  'Trieste',
#  'Udine',
#  'Pesaro',
#  'Venezia Santa Maria Maggiore',
#  'Venezia Giudecca',
#  'Verona',
#  'Avezzano',
#  'Campobasso',
#  'Alba',
#  'Cassino',
#  'Chieti',
#  'Asti',
#  'Civitavecchia Giuseppe Passerini',
#  'Chiavari',
#  'Frosinone',
#  'Cuneo',
#  'Trento',
#  'Brissogne - Aosta',
#  'Isernia',
#  'Genova Pontedecimo',
#  'Larino',
#  'Imperia',
#  'Ivrea',
#  'Paliano',
#  'La Spezia',
#  'Rieti',
#  'Roma Regina Coeli',
#  'Saluzzo',
#  'Roma Rebibbia',
#  'Roma Rebibbia IIIª casa',
#  'Roma Rebibbia femminile',
#  'Verbania',
#  'Padova Nuovo Complesso',
#  'Sulmona',
#  'Vasto',
#  'Velletri',
#  'Torino',
#  'Alessandria Cantiello, Gaeta',
#  'Reggio Calabria Giuseppe Panzera',
#  'Alessandria San Michele',
#  'Altamura',
#  'Arezzo',
#  'Bari',
#  'Firenze Sollicciano',
#  'Brindisi',
#  'Grosseto',
#  'Foggia',
#  'Livorno Gorgona',
#  'Livorno',
#  'Lucca',
#  'Matera',
#  'Melfi',
#  'Potenza',
#  'Orvieto',
#  'San Severo',
#  'Trani',
#  'Pisa',
#  'Turi',
#  'Pistoia',
#  'Alghero',
#  'Prato',
#  'Arbus',
#  'San Gimignano',
#  'Siena',
#  'Spoleto',
#  'Cagliari Uta',
#  'Agrigento',
#  'Lanusei',
#  'Nuoro',
#  'Barcellona Pozzo di Gotto',
#  'Onanì',
#  'Oristano',
#  'Tempio Pausania',
#  'Ragusa',
#  'Sciacca',
#  'Napoli Poggioreale',
#  'Napoli Secondigliano',
#  'Brescia Canton Monbello',
#  'Milano San Vittore',
#  'Milano San Vittore femminile',
#  'Firenze Mario Gozzini',
#  'Porto Azzurro',
#  'Terni',
#  'Sanremo',
#  'Ancona Barcaglione',
#  'Ancona Montacuto',
#  'Avellino',
#  'Teramo',
#  'Vicenza',
#  'Massa',
#  'Massa Marittima',
#  'Lecce',
#  'Pescara',
#  'Pozzuoli',
#  'Laureana di Borrello',
#  'Trani femminile',
#  'Augusta',
#  'Caltagirone',
#  'Castelvetrano',
#  'Catania Piazza Lanza',
#  'Enna',
#  'Favignana',
#  'Gela',
#  'Giarre',
#  'Noto',
#  'San Cataldo',
#  'Termini Imerese',
#  'Trapani',
#  'Biella',
#  'Volterra',
#  'Civitavecchia Nuovo Complesso',
#  'Tolmezzo',
#  'Caltanissetta',
#  'Belluno',
#  'Cosenza',
#  'Bollate',
#  'Vallo della Lucania',
#  'Benevento',
#  'Viterbo',
#  'Bergamo',
#  'Isili',
#  'Arienzo',
#  "L'Aquila",
#  'Novara',
#  'Messina',
#  'Catania Bicocca',
#  "Sant'Angelo dei Lombardi",
#  'Lauro',
#  'Palermo Ucciardone',
#  'Sassari',
#  'Perugia',
#  'Vercelli',
#  'Vigevano',
#  'Locri',
#  'Roma Rebibbia Nuovo Complesso',
#  'Castrovillari',
#  'Lucera',
#  'Latina',
#  'Piazza Armerina',
#  'Lanciano',
#  'Palermo Pagliarelli',
#  'Salerno',
#  'Taranto',
#  'Fossano',
#  'Opera',
#  'Genova Marassi',
#  'Reggio Emilia',
#  'Rimini',
#  'Ferrara',
#  'Piacenza',
#  'Bologna',
#  'Ravenna',
#  'Parma',
#  'Forlì',
#  'Modena',
#  'Siracusa']

# %%
df_copy = df
df_copy.head(4)
# Out:
#   Regione di detenzione Sigla Provincia  Istituto Tipo istituto  \
# 0               ABRUZZO              AQ  AVEZZANO            CC
# 1               ABRUZZO              AQ  L'AQUILA            CC
# 2               ABRUZZO              AQ   SULMONA            CR
# 3               ABRUZZO              CH    CHIETI            CC
#
#    Capienza Regolamentare  Detenuti presenti - totale  \
# 0                      53                          71
# 1                     228                         166
# 2                     323                         443
# 3                      79                         140
#
#    Detenuti presenti - donne  Detenuti presenti - stranieri  \
# 0                          0                             24
# 1                         12                             15
# 2                          0                             10
# 3                         36                             35
#
#   Ultimo aggiornamento          ID
# 0           2024-08-31  SST1418233
# 1           2024-08-31  SST1418233
# 2           2024-08-31  SST1418233
# 3           2024-08-31  SST1418233

# %%
def standardize_name(name):
    match, score = process.extractOne(name, standard_names)
    return match if score >= 90 else name  # Adjust score threshold as needed
# Apply fuzzy matching to standardize names
df_copy['Istituto'] = df_copy['Istituto'].apply(standardize_name)

# %%
sorted(df_copy['Istituto'].unique())
# Out:
# ['Agrigento',
#  'Alba',
#  'Alessandria Cantiello, Gaeta',
#  'Alessandria San Michele',
#  'Alghero',
#  'Altamura',
#  'Ancona Barcaglione',
#  'Arbus',
#  'Arezzo',
#  'Ariano Irpino',
#  'Arienzo',
#  'Ascoli Piceno',
#  'Asti',
#  'Augusta',
#  'Avellino',
#  'Aversa',
#  'Avezzano',
#  'BRESCIA "N. FISCHIONE" CANTON MONBELLO',
#  'BRESCIA "NERIO FISCHIONE" CANTON MONBELLO',
#  'Barcellona Pozzo di Gotto',
#  'Bari',
#  'Belluno',
#  'Benevento',
#  'Bergamo',
#  'Biella',
#  'Bollate',
#  'Bologna',
#  'Bolzano',
#  'Brescia Verziano',
#  'Brindisi',
#  'Brissogne - Aosta',
#  'Busto Arsizio',
#  'CAGLIARI "E.SCALAS"',
#  'CAGLIARI "ETTORE SCALAS"',
#  'CAMERINO',
#  'CIVITAVECCHIA "N.C."',
#  'Caltagirone',
#  'Caltanissetta',
#  'Campobasso',
#  'Carinola',
#  'Cassino',
#  'Castelfranco Emilia',
#  'Castelvetrano',
#  'Castrovillari',
#  'Catania Bicocca',
#  'Catania Piazza Lanza',
#  'Catanzaro',
#  'Chiavari',
#  'Chieti',
#  'Civitavecchia Giuseppe Passerini',
#  'Como',
#  'Cosenza',
#  'Cremona',
#  'Crotone',
#  'Cuneo',
#  'Eboli',
#  'Enna',
#  "FORLI'",
#  'Favignana',
#  'Fermo',
#  'Ferrara',
#  'Firenze Mario Gozzini',
#  'Firenze Sollicciano',
#  'Foggia',
#  'Fossano',
#  'Fossombrone',
#  'Frosinone',
#  'Gela',
#  'Genova Marassi',
#  'Genova Pontedecimo',
#  'Giarre',
#  'Gorizia',
#  'Grosseto',
#  'Imperia',
#  'Isernia',
#  'Isili',
#  'Ivrea',
#  "L'Aquila",
#  'La Spezia',
#  'Lanciano',
#  'Lanusei',
#  'Larino',
#  'Latina',
#  'Laureana di Borrello',
#  'Lauro',
#  'Lecce',
#  'Lecco',
#  'Livorno',
#  'Livorno Gorgona',
#  'Locri',
#  'Lodi',
#  'Lucca',
#  'Lucera',
#  'MILANO "F. DI CATALDO" SAN VITTORE',
#  'MILANO "FRANCESCO DI CATALDO" SAN VITTORE',
#  'Mantova',
#  'Massa',
#  'Massa Marittima',
#  'Matera',
#  'Melfi',
#  'Messina',
#  'Modena',
#  'Monza',
#  'NAPOLI "G. SALVIA" POGGIOREALE',
#  'NAPOLI "GIUSEPPE SALVIA" POGGIOREALE',
#  'NAPOLI "P. MANDATO" SECONDIGLIANO',
#  'NAPOLI "PASQUALE MANDATO" SECONDIGLIANO',
#  'Noto',
#  'Novara',
#  'Nuoro',
#  'Onanì',
#  'Opera',
#  'Oristano',
#  'Orvieto',
#  'PALERMO "A. LORUSSO" PAGLIARELLI',
#  'PALERMO "ANTONIO LORUSSO" PAGLIARELLI',
#  'PALERMO "C. DI BONA" UCCIARDONE',
#  'PALERMO "CALOGERO DI BONA" UCCIARDONE',
#  'Padova',
#  'Paliano',
#  'Palmi',
#  'Paola',
#  'Parma',
#  'Pavia',
#  'Perugia',
#  'Pesaro',
#  'Pescara',
#  'Piacenza',
#  'Piazza Armerina',
#  'Pisa',
#  'Pistoia',
#  'Pordenone',
#  'Porto Azzurro',
#  'Potenza',
#  'Pozzuoli',
#  'Prato',
#  'ROMA "G. STEFANINI" REBIBBIA FEMMINILE',
#  'ROMA "GERMANA STEFANINI" REBIBBIA FEMMINILE',
#  'ROMA "R. CINOTTI" REBIBBIA N.C.1',
#  'ROMA "RAFFAELE CINOTTI" REBIBBIA N.C.1',
#  'ROMA "REBIBBIA TERZA CASA"',
#  'Ragusa',
#  'Ravenna',
#  'Reggio Calabria Arghillà',
#  'Reggio Calabria Giuseppe Panzera',
#  'Reggio Emilia',
#  'Rieti',
#  'Rimini',
#  'Roma Rebibbia',
#  'Roma Regina Coeli',
#  'Rossano',
#  'Rovigo',
#  'SAN REMO "N.C."',
#  'Salerno',
#  'Saluzzo',
#  'San Cataldo',
#  'San Gimignano',
#  'San Severo',
#  'Sanremo',
#  "Sant'Angelo dei Lombardi",
#  'Santa Maria Capua Vetere',
#  'Sassari',
#  'Sciacca',
#  'Siena',
#  'Siracusa',
#  'Sondrio',
#  'Spoleto',
#  'Sulmona',
#  'Taranto',
#  'Tempio Pausania',
#  'Teramo',
#  'Termini Imerese',
#  'Terni',
#  'Tolmezzo',
#  'Torino',
#  'Trani',
#  'Trapani',
#  'Trento',
#  'Treviso',
#  'Trieste',
#  'Turi',
#  'Udine',
#  'Vallo della Lucania',
#  'Varese',
#  'Vasto',
#  'Velletri',
#  'Venezia Giudecca',
#  'Venezia Santa Maria Maggiore',
#  'Verbania',
#  'Vercelli',
#  'Verona',
#  'Vibo Valentia',
#  'Vicenza',
#  'Vigevano',
#  'Viterbo',
#  'Voghera',
#  'Volterra']

# %% [markdown]
# Because the names that did not match are uppercase, we can identify them easily and proceed with a mapping.

# %%
sorted(df_copy[df_copy['Istituto'].str.isupper()]['Istituto'].unique())
# Out:
# ['BRESCIA "N. FISCHIONE" CANTON MONBELLO',
#  'BRESCIA "NERIO FISCHIONE" CANTON MONBELLO',
#  'CAGLIARI "E.SCALAS"',
#  'CAGLIARI "ETTORE SCALAS"',
#  'CAMERINO',
#  'CIVITAVECCHIA "N.C."',
#  "FORLI'",
#  'MILANO "F. DI CATALDO" SAN VITTORE',
#  'MILANO "FRANCESCO DI CATALDO" SAN VITTORE',
#  'NAPOLI "G. SALVIA" POGGIOREALE',
#  'NAPOLI "GIUSEPPE SALVIA" POGGIOREALE',
#  'NAPOLI "P. MANDATO" SECONDIGLIANO',
#  'NAPOLI "PASQUALE MANDATO" SECONDIGLIANO',
#  'PALERMO "A. LORUSSO" PAGLIARELLI',
#  'PALERMO "ANTONIO LORUSSO" PAGLIARELLI',
#  'PALERMO "C. DI BONA" UCCIARDONE',
#  'PALERMO "CALOGERO DI BONA" UCCIARDONE',
#  'ROMA "G. STEFANINI" REBIBBIA FEMMINILE',
#  'ROMA "GERMANA STEFANINI" REBIBBIA FEMMINILE',
#  'ROMA "R. CINOTTI" REBIBBIA N.C.1',
#  'ROMA "RAFFAELE CINOTTI" REBIBBIA N.C.1',
#  'ROMA "REBIBBIA TERZA CASA"',
#  'SAN REMO "N.C."']

# %%
institute_mapping = {
    'BRESCIA "N. FISCHIONE" CANTON MONBELLO': 'Brescia Canton Monbello',
    'BRESCIA "NERIO FISCHIONE" CANTON MONBELLO': 'Brescia Canton Monbello',
    'CAGLIARI "E.SCALAS"': 'Cagliari Uta',
    'CAGLIARI "ETTORE SCALAS"': 'Cagliari Uta',
    'CAMERINO': 'Camerino',
    'CIVITAVECCHIA "N.C."': 'Civitavecchia Nuovo Complesso',
    "FORLI'": 'Forlì',
    'MILANO "F. DI CATALDO" SAN VITTORE': 'Milano San Vittore',
    'MILANO "FRANCESCO DI CATALDO" SAN VITTORE': 'Milano San Vittore',
    'NAPOLI "G. SALVIA" POGGIOREALE': 'Napoli Poggioreale',
    'NAPOLI "GIUSEPPE SALVIA" POGGIOREALE': 'Napoli Poggioreale',
    'NAPOLI "P. MANDATO" SECONDIGLIANO': 'Napoli Secondigliano',
    'NAPOLI "PASQUALE MANDATO" SECONDIGLIANO': 'Napoli Secondigliano',
    'PALERMO "A. LORUSSO" PAGLIARELLI': 'Palermo Pagliarelli',
    'PALERMO "ANTONIO LORUSSO" PAGLIARELLI': 'Palermo Pagliarelli',
    'PALERMO "C. DI BONA" UCCIARDONE': 'Palermo Ucciardone',
    'PALERMO "CALOGERO DI BONA" UCCIARDONE': 'Palermo Ucciardone',
    'ROMA "G. STEFANINI" REBIBBIA FEMMINILE': 'Roma Rebibbia Femminile',
    'ROMA "GERMANA STEFANINI" REBIBBIA FEMMINILE': 'Roma Rebibbia Femminile',
    'ROMA "R. CINOTTI" REBIBBIA N.C.1': 'Roma Rebibbia',
    'ROMA "RAFFAELE CINOTTI" REBIBBIA N.C.1': 'Roma Rebibbia',
    'ROMA "REBIBBIA TERZA CASA"': 'Roma Rebibbia III Casa',
    'SAN REMO "N.C."': 'Sanremo',
}

df_copy['Istituto'] = df_copy['Istituto'].replace(institute_mapping)

# Check the updated unique values
df_copy['Istituto'].unique()
# Out:
# array(['Avezzano', "L'Aquila", 'Sulmona', 'Chieti', 'Lanciano', 'Vasto',
#        'Pescara', 'Teramo', 'Matera', 'Melfi', 'Potenza', 'Castrovillari',
#        'Cosenza', 'Paola', 'Rossano', 'Catanzaro', 'Crotone',
#        'Laureana di Borrello', 'Locri', 'Palmi',
#        'Reggio Calabria Arghillà', 'Reggio Calabria Giuseppe Panzera',
#        'Vibo Valentia', 'Ariano Irpino', 'Avellino', 'Lauro',
#        "Sant'Angelo dei Lombardi", 'Benevento', 'Arienzo', 'Aversa',
#        'Carinola', 'Santa Maria Capua Vetere', 'Napoli Poggioreale',
#        'Napoli Secondigliano', 'Pozzuoli', 'Eboli', 'Salerno',
#        'Vallo della Lucania', 'Bologna', 'Ferrara', 'Forlì',
#        'Castelfranco Emilia', 'Modena', 'Piacenza', 'Parma', 'Ravenna',
#        'Reggio Emilia', 'Rimini', 'Gorizia', 'Pordenone', 'Trieste',
#        'Tolmezzo', 'Udine', 'Cassino', 'Frosinone', 'Paliano', 'Latina',
#        'Rieti', 'Civitavecchia Giuseppe Passerini',
#        'Civitavecchia Nuovo Complesso', 'Roma Rebibbia Femminile',
#        'Roma Rebibbia', 'Roma Rebibbia III Casa', 'Roma Regina Coeli',
#        'Velletri', 'Viterbo', 'Chiavari', 'Genova Marassi',
#        'Genova Pontedecimo', 'Imperia', 'Sanremo', 'La Spezia', 'Bergamo',
#        'Brescia Canton Monbello', 'Brescia Verziano', 'Como', 'Cremona',
#        'Lecco', 'Lodi', 'Bollate', 'Milano San Vittore', 'Monza', 'Opera',
#        'Mantova', 'Pavia', 'Vigevano', 'Voghera', 'Sondrio',
#        'Busto Arsizio', 'Varese', 'Ancona Barcaglione', 'Ascoli Piceno',
#        'Fermo', 'Fossombrone', 'Pesaro', 'Campobasso', 'Larino',
#        'Isernia', 'Alessandria Cantiello, Gaeta',
#        'Alessandria San Michele', 'Asti', 'Biella', 'Alba', 'Cuneo',
#        'Fossano', 'Saluzzo', 'Novara', 'Ivrea', 'Torino', 'Verbania',
#        'Vercelli', 'Altamura', 'Bari', 'Turi', 'Brindisi', 'Trani',
#        'Foggia', 'Lucera', 'San Severo', 'Lecce', 'Taranto', 'Arbus',
#        'Cagliari Uta', 'Isili', 'Lanusei', 'Nuoro', 'Onanì', 'Oristano',
#        'Alghero', 'Sassari', 'Tempio Pausania', 'Agrigento', 'Sciacca',
#        'Caltanissetta', 'Gela', 'San Cataldo', 'Caltagirone',
#        'Catania Bicocca', 'Catania Piazza Lanza', 'Giarre', 'Enna',
#        'Piazza Armerina', 'Barcellona Pozzo di Gotto', 'Messina',
#        'Palermo Pagliarelli', 'Palermo Ucciardone', 'Termini Imerese',
#        'Ragusa', 'Augusta', 'Noto', 'Siracusa', 'Castelvetrano',
#        'Favignana', 'Trapani', 'Arezzo', 'Firenze Mario Gozzini',
#        'Firenze Sollicciano', 'Grosseto', 'Massa Marittima', 'Livorno',
#        'Livorno Gorgona', 'Porto Azzurro', 'Lucca', 'Massa', 'Pisa',
#        'Volterra', 'Prato', 'Pistoia', 'San Gimignano', 'Siena',
#        'Bolzano', 'Trento', 'Perugia', 'Spoleto', 'Orvieto', 'Terni',
#        'Brissogne - Aosta', 'Belluno', 'Padova', 'Rovigo', 'Treviso',
#        'Venezia Giudecca', 'Venezia Santa Maria Maggiore', 'Vicenza',
#        'Verona', 'Camerino'], dtype=object)

# %%
df_copy.sample(5)
# Out:
#       Regione di detenzione Sigla Provincia            Istituto Tipo istituto  \
# 3970                TOSCANA              PT             Pistoia            CC
# 2295               CALABRIA              CZ           Catanzaro            CC
# 12813             LOMBARDIA              LC               Lecco            CC
# 2361              LOMBARDIA              MI  Milano San Vittore            CC
# 6858               CALABRIA              RC               Locri            CC
#
#        Capienza Regolamentare  Detenuti presenti - totale  \
# 3970                       76                          59
# 2295                      682                         617
# 12813                      53                          72
# 2361                      749                         994
# 6858                       84                         108
#
#        Detenuti presenti - donne  Detenuti presenti - stranieri  \
# 3970                           0                             33
# 2295                           0                             98
# 12813                          0                             38
# 2361                          86                            630
# 6858                           0                             35
#
#       Ultimo aggiornamento         ID
# 3970            2022-12-31  SST410259
# 2295            2023-08-31  SST442883
# 12813           2019-01-31  SST168760
# 2361            2023-08-31  SST442883
# 6858            2021-08-31  SST345758

# %%
# # remove duplicate data from Dec 2021
# df_copy = df_copy[df_copy['ID'] != 'SST360932']

# %%
df_copy = df_copy.sort_values(['Ultimo aggiornamento'], ascending=False)
df_copy.tail()
# Out:
#       Regione di detenzione Sigla Provincia           Istituto Tipo istituto  \
# 12799                 LAZIO              RM  Roma Regina Coeli            CC
# 12800                 LAZIO              RM           Velletri            CC
# 12801                 LAZIO              VT            Viterbo            CC
# 12802               LIGURIA              GE           Chiavari            CR
# 12923                VENETO              VI            Vicenza            CC
#
#        Capienza Regolamentare  Detenuti presenti - totale  \
# 12799                     616                         984
# 12800                     411                         569
# 12801                     432                         548
# 12802                      45                          42
# 12923                     286                         322
#
#        Detenuti presenti - donne  Detenuti presenti - stranieri  \
# 12799                          0                            525
# 12800                          0                            191
# 12801                          0                            289
# 12802                          0                             14
# 12923                          0                            189
#
#       Ultimo aggiornamento         ID
# 12799           2019-01-31  SST168760
# 12800           2019-01-31  SST168760
# 12801           2019-01-31  SST168760
# 12802           2019-01-31  SST168760
# 12923           2019-01-31  SST168760

# %%
df_copy.to_csv('../outputs/clean/bulletines.csv', index=False, encoding="UTF-8-sig")
