# %% [markdown]
# ## Bulletines Scraper
#
# This notebook uses the links previously scraped to retrieve data from each monthly bulletine published by the Italian Ministry of Justice regarding inmates and stores the raw data in `outputs/raw/bulletines.csv`.

# %%
import pandas as pd
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
from time import sleep
import random

# %%
# Import links
links_df = pd.read_csv('../outputs/clean/bulletines_links.csv')
links_df.head()
# Out:
#            ID Ultimo aggiornamento  \
# 0  SST1418233           2024-08-31
# 1  SST1415275           2024-07-31
# 2  SST1410601           2024-06-30
# 3  SST1407300           2024-05-31
# 4  SST1402560           2024-04-30
#
#                                            Hyperlink
# 0  https://www.giustizia.it/giustizia/it/mg_1_14_...
# 1  https://www.giustizia.it/giustizia/it/mg_1_14_...
# 2  https://www.giustizia.it/giustizia/it/mg_1_14_...
# 3  https://www.giustizia.it/giustizia/it/mg_1_14_...
# 4  https://www.giustizia.it/giustizia/it/mg_1_14_...

# %%
# "Hey, open up a browser"
playwright = await async_playwright().start()
browser = await playwright.firefox.launch()
context = await browser.new_context(viewport={'width': 1280, 'height': 800})
# Create a new browser window
page = await context.new_page()

print("Opening up the browser...")

data = []
headers = [
    'Regione di detenzione',
    'Sigla Provincia',
    'Istituto',
    'Tipo istituto',
    'Capienza Regolamentare',
    'Detenuti presenti - totale',
    'Detenuti presenti - donne',
    'Detenuti presenti - stranieri',
    'Ultimo aggiornamento',
    'ID',]

for index, row in links_df.iterrows():

    url = row['Hyperlink']
    id_value = row['ID']
    date_value = row['Ultimo aggiornamento']

    # Attempt to navigate to the URL. Retry if timeout occurs.
    retry = 0
    while retry < 5:
        try:
            print(f"Going to {url}")
            await page.goto(url, timeout=60000)
            await page.wait_for_timeout(5000)
            sleep(random.randint(1, 5))

            # Scrape the content
            content = await page.content()
            soup = BeautifulSoup(content, "html.parser")
            rows = soup.find_all("tr")


            for row in rows[2:]:  # Skipping the header rows
                cells = row.find_all("td")
                row_data = [cell.get_text(separator=" ").strip() for cell in cells]

                # Append the Date and ID values to the row_data
                row_data.extend([date_value, id_value])
                data.append(row_data)
            print(f"Scraped page id {id_value}")
            print("#######")
            sleep(random.randint(1, 5))
            break

        except Exception as e:
            print(f"Timeout while loading {e}, retrying...")

            # Close current browser, wait and reopen
            print("Reinitializing browser...")
            await browser.close()
            sleep(random.randint(1,5))
            browser = await playwright.firefox.launch()
            context = await browser.new_context(viewport={'width': 1280, 'height': 800})
            page = await context.new_page()

            retry += 1

await browser.close()
await playwright.stop()

# Create a pandas DataFrame
df = pd.DataFrame(data, columns=headers)
# Out:
# Opening up the browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST1418233
# Scraped page id SST1418233
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST1415275
# Scraped page id SST1415275
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST1410601
# Scraped page id SST1410601
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST1407300
# Scraped page id SST1407300
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST1402560
# Scraped page id SST1402560
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST466343
# Scraped page id SST466343
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST462936
# Scraped page id SST462936
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST459023
# Scraped page id SST459023
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST454090
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST454090
# Scraped page id SST454090
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST449508
# Scraped page id SST449508
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST447996
# Scraped page id SST447996
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST446492
# Scraped page id SST446492
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST442883
# Scraped page id SST442883
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST439073
# Scraped page id SST439073
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST436158
# Scraped page id SST436158
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST431165
# Scraped page id SST431165
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST426356
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST426356
# Scraped page id SST426356
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST423466
# Scraped page id SST423466
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST418777
# Scraped page id SST418777
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST414676
# Scraped page id SST414676
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST410259
# Scraped page id SST410259
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST405710
# Scraped page id SST405710
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST401327
# Scraped page id SST401327
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST398014
# Scraped page id SST398014
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST393944
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST393944
# Scraped page id SST393944
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST390144
# Scraped page id SST390144
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST386394
# Scraped page id SST386394
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST382391
# Scraped page id SST382391
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST377961
# Scraped page id SST377961
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST374094
# Scraped page id SST374094
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST369465
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST369465
# Scraped page id SST369465
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST365608
# Scraped page id SST365608
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST360932
# Scraped page id SST360932
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST357666
# Scraped page id SST357666
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST352771
# Scraped page id SST352771
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST348572
# Scraped page id SST348572
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST345758
# Scraped page id SST345758
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST342771
# Scraped page id SST342771
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST338675
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST338675
# Scraped page id SST338675
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST334403
# Scraped page id SST334403
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST331096
# Scraped page id SST331096
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST327697
# Scraped page id SST327697
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST323234
# Scraped page id SST323234
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST319895
# Scraped page id SST319895
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST314850
# Scraped page id SST314850
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST308223
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST308223
# Scraped page id SST308223
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST301069
# Scraped page id SST301069
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST301066
# Scraped page id SST301066
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST289764
# Scraped page id SST289764
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST285903
# Scraped page id SST285903
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST281553
# Scraped page id SST281553
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST276692
# Scraped page id SST276692
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST271286
# Scraped page id SST271286
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST267794
# Scraped page id SST267794
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST250612
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST250612
# Scraped page id SST250612
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST245520
# Scraped page id SST245520
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST238852
# Scraped page id SST238852
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST231374
# Scraped page id SST231374
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST225673
# Scraped page id SST225673
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST219309
# Scraped page id SST219309
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST212437
# Timeout while loading Timeout 60000ms exceeded., retrying...
# Reinitializing browser...
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST212437
# Scraped page id SST212437
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST206215
# Scraped page id SST206215
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST199180
# Scraped page id SST199180
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST193650
# Scraped page id SST193650
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST188400
# Scraped page id SST188400
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST183024
# Scraped page id SST183024
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST173677
# Scraped page id SST173677
# #######
# Going to https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST168760
# Scraped page id SST168760
# #######

# %%
df.tail()

# %%
len(df)

# %%
# Store df
df.to_csv('../outputs/raw/bulletines_raw.csv', index=False, encoding="UTF-8-sig")
