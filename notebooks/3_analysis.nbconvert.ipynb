# %%
import pandas as pd

# %%
df = pd.read_csv('../outputs/clean/istituti_data.csv')

# %%
df.head()
# Out:
#           id                      nome                tipo  \
# 0  MII179988  Reggio Calabria Arghillà  Casa circondariale
# 1  MII172610          Brescia Verziano  Casa di reclusione
# 2  MII172320             Busto Arsizio  Casa circondariale
# 3  MII173712                      Como  Casa circondariale
# 4  MII173747                   Cremona  Casa circondariale
#
#    posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 0                  294                      0             353
# 1                   71                      0             123
# 2                  240                     11             440
# 3                  226                      0             433
# 4                  394                     10             577
#
#   posti_aggiornati_al                        asl nome_responsabile_asl  \
# 0          17/06/2024          5 Reggio Calabria               Luciano
# 1          17/06/2024  Spedali Civili di Brescia                 Luigi
# 2          17/06/2024              Busto Arsizio                  Ezia
# 3          17/06/2024                       Como              Giuseppe
# 4          17/06/2024                    CREMONA               Rossano
#
#   cognome_responsabile_asl  ... cognome_direttore ruolo_direttore  \
# 0                  Lucania  ...         Stendardo        Titolare
# 1                    Leone  ...               NaN             NaN
# 2                    Iorio  ...        Pitaniello        Titolare
# 3                  Carrano  ...           Rinaldi        Titolare
# 4                    Botto  ...            Padula        Titolare
#
#   personale_polizia_effettivi  personale_polizia_previsti  \
# 0                         133                         160
# 1                          77                          96
# 2                         180                         217
# 3                         181                         236
# 4                         169                         223
#
#    personale_amministrativi_effettivi  personale_amministrativi_previsti  \
# 0                                  12                                 32
# 1                                   2                                  0
# 2                                  14                                 21
# 3                                  15                                 23
# 4                                  16                                 23
#
#    personale_educatori_effettivi  personale_educatori_previsti  \
# 0                              5                             8
# 1                              1                             0
# 2                              3                             5
# 3                              3                             6
# 4                              6                             6
#
#    personale_polizia_aggiornato_a personale_amministrativo_aggiornato_al
# 0                      31/05/2024                             31/05/2024
# 1                      31/05/2024                             31/05/2024
# 2                      31/05/2024                             31/05/2024
# 3                      31/05/2024                             31/05/2024
# 4                      31/05/2024                             31/05/2024
#
# [5 rows x 21 columns]

# %%
last_update = df['posti_aggiornati_al'].max()
last_update
# Out:
# '17/06/2024'

# %%
df_most_recent = df[['id', 'nome', 'tipo', 'posti_regolamentari', 'posti_non_disponibili', 'posti_occupati', 'posti_aggiornati_al']]
df_most_recent
# Out:
#             id                      nome  \
# 0    MII179988  Reggio Calabria Arghillà
# 1    MII172610          Brescia Verziano
# 2    MII172320             Busto Arsizio
# 3    MII173712                      Como
# 4    MII173747                   Cremona
# ..         ...                       ...
# 206  MII173259             Castelvetrano
# 207  MII173994                 Favignana
# 208  MII178681                      Noto
# 209  MII177384                     Lauro
# 210  MII181125                  Siracusa
#
#                                          tipo  posti_regolamentari  \
# 0                          Casa circondariale                  294
# 1                          Casa di reclusione                   71
# 2                          Casa circondariale                  240
# 3                          Casa circondariale                  226
# 4                          Casa circondariale                  394
# ..                                        ...                  ...
# 206                        Casa circondariale                   44
# 207     Casa di reclusione - Giuseppe Barraco                   89
# 208  Casa di reclusione - Attilio Bonincontro                  176
# 209     Istituto custodia attenuata per madri                   50
# 210                        Casa circondariale                  545
#
#      posti_non_disponibili  posti_occupati posti_aggiornati_al
# 0                        0             353          17/06/2024
# 1                        0             123          17/06/2024
# 2                       11             440          17/06/2024
# 3                        0             433          17/06/2024
# 4                       10             577          17/06/2024
# ..                     ...             ...                 ...
# 206                      0              69          17/06/2024
# 207                      3             107          17/06/2024
# 208                      0             146          17/06/2024
# 209                      0              38          17/06/2024
# 210                      0             669          17/06/2024
#
# [211 rows x 7 columns]

# %%
df_most_recent = df_most_recent[df_most_recent['posti_aggiornati_al'] == last_update]
df_most_recent
# Out:
#             id                      nome  \
# 0    MII179988  Reggio Calabria Arghillà
# 1    MII172610          Brescia Verziano
# 2    MII172320             Busto Arsizio
# 3    MII173712                      Como
# 4    MII173747                   Cremona
# ..         ...                       ...
# 206  MII173259             Castelvetrano
# 207  MII173994                 Favignana
# 208  MII178681                      Noto
# 209  MII177384                     Lauro
# 210  MII181125                  Siracusa
#
#                                          tipo  posti_regolamentari  \
# 0                          Casa circondariale                  294
# 1                          Casa di reclusione                   71
# 2                          Casa circondariale                  240
# 3                          Casa circondariale                  226
# 4                          Casa circondariale                  394
# ..                                        ...                  ...
# 206                        Casa circondariale                   44
# 207     Casa di reclusione - Giuseppe Barraco                   89
# 208  Casa di reclusione - Attilio Bonincontro                  176
# 209     Istituto custodia attenuata per madri                   50
# 210                        Casa circondariale                  545
#
#      posti_non_disponibili  posti_occupati posti_aggiornati_al
# 0                        0             353          17/06/2024
# 1                        0             123          17/06/2024
# 2                       11             440          17/06/2024
# 3                        0             433          17/06/2024
# 4                       10             577          17/06/2024
# ..                     ...             ...                 ...
# 206                      0              69          17/06/2024
# 207                      3             107          17/06/2024
# 208                      0             146          17/06/2024
# 209                      0              38          17/06/2024
# 210                      0             669          17/06/2024
#
# [211 rows x 7 columns]

# %%
df_most_recent['posti_reali'] = df_most_recent['posti_regolamentari'] - df_most_recent['posti_non_disponibili']
df_most_recent['tasso_occupazione'] = round(df_most_recent['posti_occupati'] / df_most_recent['posti_reali'],2)
df_most_recent
# Out:
#             id                      nome  \
# 0    MII179988  Reggio Calabria Arghillà
# 1    MII172610          Brescia Verziano
# 2    MII172320             Busto Arsizio
# 3    MII173712                      Como
# 4    MII173747                   Cremona
# ..         ...                       ...
# 206  MII173259             Castelvetrano
# 207  MII173994                 Favignana
# 208  MII178681                      Noto
# 209  MII177384                     Lauro
# 210  MII181125                  Siracusa
#
#                                          tipo  posti_regolamentari  \
# 0                          Casa circondariale                  294
# 1                          Casa di reclusione                   71
# 2                          Casa circondariale                  240
# 3                          Casa circondariale                  226
# 4                          Casa circondariale                  394
# ..                                        ...                  ...
# 206                        Casa circondariale                   44
# 207     Casa di reclusione - Giuseppe Barraco                   89
# 208  Casa di reclusione - Attilio Bonincontro                  176
# 209     Istituto custodia attenuata per madri                   50
# 210                        Casa circondariale                  545
#
#      posti_non_disponibili  posti_occupati posti_aggiornati_al  posti_reali  \
# 0                        0             353          17/06/2024          294
# 1                        0             123          17/06/2024           71
# 2                       11             440          17/06/2024          229
# 3                        0             433          17/06/2024          226
# 4                       10             577          17/06/2024          384
# ..                     ...             ...                 ...          ...
# 206                      0              69          17/06/2024           44
# 207                      3             107          17/06/2024           86
# 208                      0             146          17/06/2024          176
# 209                      0              38          17/06/2024           50
# 210                      0             669          17/06/2024          545
#
#      tasso_occupazione
# 0                 1.20
# 1                 1.73
# 2                 1.92
# 3                 1.92
# 4                 1.50
# ..                 ...
# 206               1.57
# 207               1.24
# 208               0.83
# 209               0.76
# 210               1.23
#
# [211 rows x 9 columns]

# %%
df_most_recent.to_csv('../outputs/viz/most_recent.csv', index=False, encoding='UTF-8-sig')
