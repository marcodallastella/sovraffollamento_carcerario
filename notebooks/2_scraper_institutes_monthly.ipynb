# %% [markdown]
# # Scraper institutes
#
# This notebook is a monthly scraper used to retrieve information about condition in detention centers in Italy. To do so, it uses the id numbers of the various detention centers to navigate to the dedicated webpages with Selenium, store locally the html code of the page and then parse it using BeautifuSoup. The information is then stored in a pandas dataframe and saved as a csv file.

# %%
from bs4 import BeautifulSoup
import pandas as pd
from pathlib import Path
import datetime
from random import randint
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.by import By

# %%
# Collect institutes id numbers
prisons_df = pd.read_csv('../outputs/clean/istituti_penitenziari.csv')
prison_ids = prisons_df['id_istituto'].tolist()

# Get current month
current_month = datetime.datetime.now().strftime("%Y-%m")

# %%
def open_browser():
    """
    Opens a new automated browser window with all tell-tales of automated browser disabled
    """
    options = Options()
    options.add_argument("--start-maximized")

    # Enable headless mode
    # options.add_argument    
    options.add_argument("--headless")

    # remove all signs of this being an automated browser
    options.set_preference("dom.webdriver.enabled", False)
    options.set_preference('useAutomationExtension', False)
    options.set_preference("general.useragent.override", "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0")
    
    return options

def get_html(prison_id):
    # open the browser with the new options
    driver = webdriver.Firefox(options=open_browser())
    
    MAX_RETRIES = 5

    for i in range(MAX_RETRIES):
        try:
            BASE_URL = "https://www.giustizia.it/giustizia/it/dettaglio_scheda.page?s="
            page_url = BASE_URL + prison_id
            print("Fetching " + page_url)

            # Go to the page, get source code
            driver.get(page_url)
            sleep(5)
            page_html = driver.page_source
            return page_html

        except Exception as e:
            print(f"Error occurred: {e}. Retrying in 10 seconds.")
            sleep(10)
        finally:
            driver.quit()

# %%
prison_all_data = []

for prison_id in prison_ids:

    dest = Path(f"../outputs/raw/istituti/{prison_id}_{current_month}.html")

    if dest.exists() : #... load it from file
        print(f"Already have {dest}, loading!")
        page_html = open(dest).read()
    else:
        page_html = get_html(prison_id)

    # Parse the html with BeautifulSoup
    soup = BeautifulSoup(page_html, 'html.parser')

    # Nome istituto, tipo istituto
    institute_name = soup.find('h1', {'class': 'titoloIstituto'}).text.strip()
    institute_type = soup.find('h3', {'class': 'titoloIstituto'}).text.strip()

    # Tabella capienze
    table_capienze = soup.find_all('table')[0]
    posti_regolamentari = int(table_capienze.find_all('td')[0].text.strip())
    posti_non_disponibili = int(table_capienze.find_all('td')[1].text.strip())
    totale_detenuti = int(table_capienze.find_all('td')[2].text.strip())
    
    # Dati capienze aggiornati al
    target_span= soup.find('h2', text='dati aggiornati al ')
    span = target_span.find_next_sibling('span')
    dati_aggiornati_al = span.text.strip()

    # Responsabile ASL per il carcere
    target_span = soup.find('h2', text='Responsabile ASL per il carcere')
    try:
        div = target_span.find_next('div', {'class': 'listaContenutiComplessi'})
        spans = div.find_all('span', {'class': 'valoreSottocampo'})
        asl = spans[0].text.strip()
        first_name_asl = spans[1].text.strip()
        last_name_asl = spans[2].text.strip()
    except:
        asl = 'NA'
        first_name_asl = 'NA'
        last_name_asl = 'NA'

     # Direttore
    target_span = soup.find('h2', text='Direttore')
    try:
        div = target_span.find_next('div', {'class': 'listaContenutiComplessi'})
        spans = div.find_all('span', {'class': 'valoreSottocampo'})
        first_name = spans[0].text.strip()
        last_name = spans[1].text.strip()
        role = spans[2].text.strip()
    except:
        first_name = 'NA'
        last_name = 'NA'
        role = 'NA'
    
    # Staff table
    table_staff = soup.find_all('table')[1]
    polizia_penitenziaria_effettivi = int(table_staff.find_all('td')[0].text.strip())
    polizia_penitenziaria_previsti = int(table_staff.find_all('td')[1].text.strip())
    amministrativi_effettivi = int(table_staff.find_all('td')[2].text.strip())
    amministrativi_previsti = int(table_staff.find_all('td')[3].text.strip())
    educatori_effettivi = int(table_staff.find_all('td')[4].text.strip())
    educatori_previsti = int(table_staff.find_all('td')[5].text.strip())

    # Personale polizia penitenziaria aggiornato al
    target_span= soup.find('h2', text='personale polizia penitenziaria aggiornato al')
    try:
        span = target_span.find_next_sibling('span')
        personale_polizia_aggiornato_al = span.text.strip()
    except:
        personale_polizia_aggiornato_al = 'NA'

    # Personale amministrativo aggiornato al
    target_span= soup.find('h2', text='personale amministrativo aggiornato al')
    try:
        span = target_span.find_next_sibling('span')
        personale_amministrativo_aggiornato_al = span.text.strip()
    except:
        personale_amministrativo_aggiornato_al = 'NA'


    
    prison_data = [
        [
        prison_id,
        institute_name,
        institute_type,
        posti_regolamentari,
        posti_non_disponibili,
        totale_detenuti,
        dati_aggiornati_al,
        asl,
        first_name_asl,
        last_name_asl,
        first_name,
        last_name,
        role,
        polizia_penitenziaria_effettivi,
        polizia_penitenziaria_previsti,
        amministrativi_effettivi,
        amministrativi_previsti,
        educatori_effettivi,
        educatori_previsti,
        personale_polizia_aggiornato_al,
        personale_amministrativo_aggiornato_al
        ]
        ]

    prison_all_data.extend(prison_data)

    print("#########")

prison_headers = [
    'prison_id',
    'institute_name',
    'institute_type',
    'posti_regolamentari',
    'posti_non_disponibili',
    'totale_detenuti',
    'dati_aggiornati_al',
    'asl',
    'nome_responsabile_asl',
    'cognome_responsabile_asl',
    'nome_direttore',
    'cognome_direttore',
    'ruolo_direttore',
    'polizia_penitenziaria_effettivi',
    'polizia_penitenziaria_previsti',
    'amministrativi_effettiv',
    'amministrativi_previst',
    'educatori_effettivi',
    'educatori_previsti',
    'personale_polizia_aggiornato_a',
    'personale_amministrativo_aggiornato_al'

]

prison_data_df = pd.DataFrame(prison_all_data, columns=prison_headers)

prison_data_df.to_csv('../outputs/clean/istituti_penitenziari_data.csv', index=False, encoding="UTF-8-sig")
# Out:
# Already have ../outputs/raw/istituti/MII179988_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172610_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172827_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172320_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173712_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173747_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177436_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178027_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178072_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178659_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179237_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII182910_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181346_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181703_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181924_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179733_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173311_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173324_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177996_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179342_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179353_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180415_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181908_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII159053_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172187_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173101_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173784_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172580_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176719_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180426_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181079_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181691_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179290_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180487_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179913_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180424_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII159065_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173237_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII174501_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181645_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176424_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181661_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181672_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179818_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181863_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181847_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181891_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII182440_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173088_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII157783_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173114_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173364_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII159069_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173688_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173356_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176437_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173764_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181636_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172814_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176759_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176414_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177134_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176703_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177107_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177323_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176749_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176781_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179331_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176788_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178700_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII169535_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180401_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180437_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180380_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180356_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180348_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181870_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181880_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179299_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181371_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181820_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181839_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181424_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181934_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158919_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179995_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158924_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172277_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158948_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181678_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII174720_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172623_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176743_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176375_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177498_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177463_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178045_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178035_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178124_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178141_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179938_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179280_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180476_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181377_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181434_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII182919_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181681_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179896_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158935_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179958_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158945_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180458_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181115_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181358_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172835_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158910_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177118_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179224_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172222_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178003_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179274_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181091_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181385_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178148_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179965_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181109_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178666_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178672_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180370_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172592_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158895_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178501_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176771_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII174825_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179781_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179932_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181407_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180465_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158944_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158941_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172011_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181392_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177332_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181918_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178085_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178115_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177420_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179830_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179945_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177346_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181440_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII159314_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173006_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173259_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173285_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173301_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173813_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173994_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176451_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176714_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178681_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179324_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179306_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179856_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180451_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181401_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181625_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII159060_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172332_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179876_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172208_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII177384_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181417_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173063_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII158901_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172344_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173341_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII173265_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII160204_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII152284_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII176403_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII182339_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII180001_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII174686_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179842_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII172508_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179981_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII179364_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII178638_2024-03.html, loading!
# #########
# Already have ../outputs/raw/istituti/MII181125_2024-03.html, loading!
# #########
