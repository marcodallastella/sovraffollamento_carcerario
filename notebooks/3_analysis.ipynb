# %%
import pandas as pd

# %%
# Reading csv file
df = pd.read_csv('../outputs/clean/istituti_data.csv')
df.head()
# Out:
#           id                      nome                tipo  \
# 0  MII179988  Reggio Calabria Arghillà  Casa circondariale
# 1  MII172610          Brescia Verziano  Casa di reclusione
# 2  MII172320             Busto Arsizio  Casa circondariale
# 3  MII173712                      Como  Casa circondariale
# 4  MII173747                   Cremona  Casa circondariale
#
#    posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 0                  294                      0             353
# 1                   71                      0             123
# 2                  240                     11             440
# 3                  226                      0             433
# 4                  394                     10             577
#
#   posti_aggiornati_al                        asl nome_responsabile_asl  \
# 0             6/17/24          5 Reggio Calabria               Luciano
# 1             6/17/24  Spedali Civili di Brescia                 Luigi
# 2             6/17/24              Busto Arsizio                  Ezia
# 3             6/17/24                       Como              Giuseppe
# 4             6/17/24                    CREMONA               Rossano
#
#   cognome_responsabile_asl  ... cognome_direttore ruolo_direttore  \
# 0                  Lucania  ...         Stendardo        Titolare
# 1                    Leone  ...               NaN             NaN
# 2                    Iorio  ...        Pitaniello        Titolare
# 3                  Carrano  ...           Rinaldi        Titolare
# 4                    Botto  ...            Padula        Titolare
#
#   personale_polizia_effettivi  personale_polizia_previsti  \
# 0                         133                         160
# 1                          77                          96
# 2                         180                         217
# 3                         181                         236
# 4                         169                         223
#
#    personale_amministrativi_effettivi  personale_amministrativi_previsti  \
# 0                                  12                                 32
# 1                                   2                                  0
# 2                                  14                                 21
# 3                                  15                                 23
# 4                                  16                                 23
#
#    personale_educatori_effettivi  personale_educatori_previsti  \
# 0                              5                             8
# 1                              1                             0
# 2                              3                             5
# 3                              3                             6
# 4                              6                             6
#
#    personale_polizia_aggiornato_a personale_amministrativo_aggiornato_al
# 0                      31/05/2024                             31/05/2024
# 1                      31/05/2024                             31/05/2024
# 2                      31/05/2024                             31/05/2024
# 3                      31/05/2024                             31/05/2024
# 4                      31/05/2024                             31/05/2024
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 1. Most recent
# Get most recent data to build current map.

# %%
df['posti_aggiornati_al'].value_counts()
# Out:
# 8/13/24       197
# 6/17/24       193
# 8/3/24        190
# 10/1/24       190
# 10/5/24       190
# 2024-10-05    190
# 10/05/24      190
# 10/8/24       189
# Name: posti_aggiornati_al, dtype: int64

# %%
# Get the most recent update
df['posti_aggiornati_al'] = pd.to_datetime(df['posti_aggiornati_al'], format='%m/%d/%y')
last_update = df['posti_aggiornati_al'].max()
last_update
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 # Get the most recent update
# ----> 2 df['posti_aggiornati_al'] = pd.to_datetime(df['posti_aggiornati_al'], format='%m/%d/%y')
#       3 last_update = df['posti_aggiornati_al'].max()
#       4 last_update
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1064, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1062             result = arg.tz_localize(tz)
#    1063 elif isinstance(arg, ABCSeries):
# -> 1064     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1065     if not cache_array.empty:
#    1066         result = arg.map(cache_array)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:229, in _maybe_cache(arg, format, cache, convert_listlike)
#     227 unique_dates = unique(arg)
#     228 if len(unique_dates) < len(arg):
# --> 229     cache_dates = convert_listlike(unique_dates, format)
#     230     # GH#45319
#     231     try:
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:430, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     427         format = None
#     429 if format is not None:
# --> 430     res = _to_datetime_with_format(
#     431         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     432     )
#     433     if res is not None:
#     434         return res
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:538, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     535         return _box_as_indexlike(result, utc=utc, name=name)
#     537 # fallback
# --> 538 res = _array_strptime_with_fallback(
#     539     arg, name, tz, fmt, exact, errors, infer_datetime_format
#     540 )
#     541 return res
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:473, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     470 utc = tz == "utc"
#     472 try:
# --> 473     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     474 except OutOfBoundsDatetime:
#     475     if errors == "raise":
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/_libs/tslibs/strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2024-10-05' does not match format '%m/%d/%y' (match)

# %%
# Create df with only most recent data available
df_most_recent = df[['id', 'nome', 'tipo', 'posti_regolamentari', 'posti_non_disponibili', 'posti_occupati', 'posti_aggiornati_al']]
df_most_recent = df_most_recent[df_most_recent['posti_aggiornati_al'] == last_update]
df_most_recent
# Out:
#             id                      nome                                tipo  \
# 383  MII179988  Reggio Calabria Arghillà                  Casa circondariale
# 384  MII172610          Brescia Verziano                  Casa di reclusione
# 385  MII172320             Busto Arsizio                  Casa circondariale
# 386  MII173712                      Como                  Casa circondariale
# 387  MII173747                   Cremona                  Casa circondariale
# ..         ...                       ...                                 ...
# 567  MII172508                   Bologna  Casa circondariale - Rocco D'Amato
# 568  MII179981                   Ravenna                  Casa circondariale
# 569  MII179364                     Parma                  Casa di reclusione
# 570  MII178638                    Modena                  Casa circondariale
# 571  MII181125                  Siracusa                  Casa circondariale
#
#      posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 383                  294                      1             340
# 384                   71                      0             122
# 385                  240                     10             436
# 386                  226                      0             438
# 387                  394                     10             551
# ..                   ...                    ...             ...
# 567                  498                      6             826
# 568                   49                      0              79
# 569                  655                     25             703
# 570                  372                      0             537
# 571                  545                      0             666
#
#     posti_aggiornati_al
# 383          2024-10-08
# 384          2024-10-08
# 385          2024-10-08
# 386          2024-10-08
# 387          2024-10-08
# ..                  ...
# 567          2024-10-08
# 568          2024-10-08
# 569          2024-10-08
# 570          2024-10-08
# 571          2024-10-08
#
# [189 rows x 7 columns]

# %%
# Adding columns for additioanl info (posti reali and tasso occupazione)
df_most_recent['posti_reali'] = df_most_recent['posti_regolamentari'] - df_most_recent['posti_non_disponibili']
df_most_recent['tasso_occupazione'] = round(df_most_recent['posti_occupati'] / df_most_recent['posti_reali'],2)
df_most_recent.head()
# Out:
#             id                      nome                tipo  \
# 383  MII179988  Reggio Calabria Arghillà  Casa circondariale
# 384  MII172610          Brescia Verziano  Casa di reclusione
# 385  MII172320             Busto Arsizio  Casa circondariale
# 386  MII173712                      Como  Casa circondariale
# 387  MII173747                   Cremona  Casa circondariale
#
#      posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 383                  294                      1             340
# 384                   71                      0             122
# 385                  240                     10             436
# 386                  226                      0             438
# 387                  394                     10             551
#
#     posti_aggiornati_al  posti_reali  tasso_occupazione
# 383          2024-10-08          293               1.16
# 384          2024-10-08           71               1.72
# 385          2024-10-08          230               1.90
# 386          2024-10-08          226               1.94
# 387          2024-10-08          384               1.43

# %%
df_most_recent.head()
# Out:
#             id                      nome                tipo  \
# 383  MII179988  Reggio Calabria Arghillà  Casa circondariale
# 384  MII172610          Brescia Verziano  Casa di reclusione
# 385  MII172320             Busto Arsizio  Casa circondariale
# 386  MII173712                      Como  Casa circondariale
# 387  MII173747                   Cremona  Casa circondariale
#
#      posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 383                  294                      1             340
# 384                   71                      0             122
# 385                  240                     10             436
# 386                  226                      0             438
# 387                  394                     10             551
#
#     posti_aggiornati_al  posti_reali  tasso_occupazione
# 383          2024-10-08          293               1.16
# 384          2024-10-08           71               1.72
# 385          2024-10-08          230               1.90
# 386          2024-10-08          226               1.94
# 387          2024-10-08          384               1.43

# %%
# reformat date as string for visualization purposes
df_most_recent['posti_aggiornati_al'] = df_most_recent['posti_aggiornati_al'].dt.strftime('%d/%m/%Y')
df_most_recent['posti_aggiornati_al'] = df_most_recent['posti_aggiornati_al'].astype(str)

# %%
# Adding institutes' information
# Read institutes' csv
df_info = pd.read_csv('../outputs/clean/istituti_info.csv')
df_info = df_info.rename(columns={'id_istituto': 'id'})
df_info.head()
# Out:
#           id codice_istituto             nome_istituto       tipo_istituto  \
# 0  MII179988            HH44  Reggio Calabria Arghillà  Casa circondariale
# 1  MII172610            BB43          Brescia Verziano  Casa di reclusione
# 2  MII172320            BB16             Busto Arsizio  Casa circondariale
# 3  MII173712            BB17                      Como  Casa circondariale
# 4  MII173747            BB18                   Cremona  Casa circondariale
#
#    latitudine  longitude  id_provveditorato nome_provveditorato  \
# 0   38.192951  15.681927                  8            Calabria
# 1   45.499606  10.187768                  1           Lombardia
# 2   45.611906   8.852052                  1           Lombardia
# 3   45.939476   9.149410                  1           Lombardia
# 4   45.133480  10.024872                  1           Lombardia
#
#                                            indirizzo          telefono
# 0     Contrada Rugola n. snc - 89135 Reggio Calabria   +39 0965 670031
# 1                    Via Flero n.157 - 25124 Brescia   +39 030 3580386
# 2  Via per Cassano Magnago n.102 - 21052 Busto Ar...  +39  0331 685777
# 3                      Via Bassone n.11 - 22100 Como   +39  031 590848
# 4                    Via Palosca n.2 - 26100 Cremona  +39  0372 450505

# %%
merged_df = pd.merge(df_most_recent, df_info, on='id')
merged_df.head()
# Out:
#           id                      nome                tipo  \
# 0  MII179988  Reggio Calabria Arghillà  Casa circondariale
# 1  MII172610          Brescia Verziano  Casa di reclusione
# 2  MII172320             Busto Arsizio  Casa circondariale
# 3  MII173712                      Como  Casa circondariale
# 4  MII173747                   Cremona  Casa circondariale
#
#    posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 0                  294                      1             340
# 1                   71                      0             122
# 2                  240                     10             436
# 3                  226                      0             438
# 4                  394                     10             551
#
#   posti_aggiornati_al  posti_reali  tasso_occupazione codice_istituto  \
# 0          08/10/2024          293               1.16            HH44
# 1          08/10/2024           71               1.72            BB43
# 2          08/10/2024          230               1.90            BB16
# 3          08/10/2024          226               1.94            BB17
# 4          08/10/2024          384               1.43            BB18
#
#               nome_istituto       tipo_istituto  latitudine  longitude  \
# 0  Reggio Calabria Arghillà  Casa circondariale   38.192951  15.681927
# 1          Brescia Verziano  Casa di reclusione   45.499606  10.187768
# 2             Busto Arsizio  Casa circondariale   45.611906   8.852052
# 3                      Como  Casa circondariale   45.939476   9.149410
# 4                   Cremona  Casa circondariale   45.133480  10.024872
#
#    id_provveditorato nome_provveditorato  \
# 0                  8            Calabria
# 1                  1           Lombardia
# 2                  1           Lombardia
# 3                  1           Lombardia
# 4                  1           Lombardia
#
#                                            indirizzo          telefono
# 0     Contrada Rugola n. snc - 89135 Reggio Calabria   +39 0965 670031
# 1                    Via Flero n.157 - 25124 Brescia   +39 030 3580386
# 2  Via per Cassano Magnago n.102 - 21052 Busto Ar...  +39  0331 685777
# 3                      Via Bassone n.11 - 22100 Como   +39  031 590848
# 4                    Via Palosca n.2 - 26100 Cremona  +39  0372 450505

# %%
# Saving csv
merged_df.to_csv('../outputs/viz/most_recent.csv', index=False, encoding='UTF-8-sig')

# %% [markdown]
# ## Historical

# %%
df_historical = df[['id', 'nome', 'tipo', 'posti_regolamentari', 'posti_non_disponibili', 'posti_occupati', 'posti_aggiornati_al']]
df_historical
# Out:
#              id                      nome                tipo  \
# 0     MII179988  Reggio Calabria Arghillà  Casa circondariale
# 1     MII172610          Brescia Verziano  Casa di reclusione
# 2     MII172320             Busto Arsizio  Casa circondariale
# 3     MII173712                      Como  Casa circondariale
# 4     MII173747                   Cremona  Casa circondariale
# ...         ...                       ...                 ...
# 1334  MII179981                   Ravenna  Casa circondariale
# 1335  MII179364                     Parma  Casa di reclusione
# 1336  MII176403                     Forlì  Casa circondariale
# 1337  MII178638                    Modena  Casa circondariale
# 1338  MII181125                  Siracusa  Casa circondariale
#
#       posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 0                     294                      0             353
# 1                      71                      0             123
# 2                     240                     11             440
# 3                     226                      0             433
# 4                     394                     10             577
# ...                   ...                    ...             ...
# 1334                   49                      0              80
# 1335                  655                     28             712
# 1336                  144                     11             151
# 1337                  372                      3             569
# 1338                  545                      0             674
#
#      posti_aggiornati_al
# 0             2024-06-17
# 1             2024-06-17
# 2             2024-06-17
# 3             2024-06-17
# 4             2024-06-17
# ...                  ...
# 1334          2024-10-05
# 1335          2024-10-05
# 1336          2024-10-05
# 1337          2024-10-05
# 1338          2024-10-05
#
# [1339 rows x 7 columns]

# %%
df_historical['posti_reali'] = df_historical['posti_regolamentari'] - df_historical['posti_non_disponibili']
df_historical
# Out:
# /var/folders/m0/g7ky_r7x67l1pv2zgg_fptx80000gn/T/ipykernel_29682/2815281607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_historical['posti_reali'] = df_historical['posti_regolamentari'] - df_historical['posti_non_disponibili']
#              id                      nome                tipo  \
# 0     MII179988  Reggio Calabria Arghillà  Casa circondariale
# 1     MII172610          Brescia Verziano  Casa di reclusione
# 2     MII172320             Busto Arsizio  Casa circondariale
# 3     MII173712                      Como  Casa circondariale
# 4     MII173747                   Cremona  Casa circondariale
# ...         ...                       ...                 ...
# 1334  MII179981                   Ravenna  Casa circondariale
# 1335  MII179364                     Parma  Casa di reclusione
# 1336  MII176403                     Forlì  Casa circondariale
# 1337  MII178638                    Modena  Casa circondariale
# 1338  MII181125                  Siracusa  Casa circondariale
#
#       posti_regolamentari  posti_non_disponibili  posti_occupati  \
# 0                     294                      0             353
# 1                      71                      0             123
# 2                     240                     11             440
# 3                     226                      0             433
# 4                     394                     10             577
# ...                   ...                    ...             ...
# 1334                   49                      0              80
# 1335                  655                     28             712
# 1336                  144                     11             151
# 1337                  372                      3             569
# 1338                  545                      0             674
#
#      posti_aggiornati_al  posti_reali
# 0             2024-06-17          294
# 1             2024-06-17           71
# 2             2024-06-17          229
# 3             2024-06-17          226
# 4             2024-06-17          384
# ...                  ...          ...
# 1334          2024-10-05           49
# 1335          2024-10-05          627
# 1336          2024-10-05          133
# 1337          2024-10-05          369
# 1338          2024-10-05          545
#
# [1339 rows x 8 columns]

# %%
pd.to_datetime(df_historical['posti_aggiornati_al'], dayfirst=True)
# Out:
# 0      2024-06-17
# 1      2024-06-17
# 2      2024-06-17
# 3      2024-06-17
# 4      2024-06-17
#           ...
# 1334   2024-10-05
# 1335   2024-10-05
# 1336   2024-10-05
# 1337   2024-10-05
# 1338   2024-10-05
# Name: posti_aggiornati_al, Length: 1339, dtype: datetime64[ns]

# %%
# Group by 'posti_aggiornati_al' and aggregate
grouped_df = df_historical.groupby('posti_aggiornati_al').agg({
    'posti_regolamentari': 'sum',
    'posti_non_disponibili': 'sum',
    'posti_occupati': 'sum',
    'posti_reali': 'sum'
}).reset_index()

# %%
grouped_df
# Out:
#   posti_aggiornati_al  posti_regolamentari  posti_non_disponibili  \
# 0          2024-06-17                52802                   4228
# 1          2024-08-03                51207                   4280
# 2          2024-08-13                54446                   4500
# 3          2024-10-01                51193                   4374
# 4          2024-10-05               102392                   8768
# 5          2024-10-08                51051                   4302
#
#    posti_occupati  posti_reali
# 0           63351        48574
# 1           61263        46927
# 2           65518        49946
# 3           61836        46819
# 4          123760        93624
# 5           61266        46749

# %%
grouped_df['tasso_occupazione'] = round(grouped_df['posti_occupati'] / grouped_df['posti_reali'], 2)
grouped_df
# Out:
#   posti_aggiornati_al  posti_regolamentari  posti_non_disponibili  \
# 0          2024-06-17                52802                   4228
# 1          2024-08-03                51207                   4280
# 2          2024-08-13                54446                   4500
# 3          2024-10-01                51193                   4374
# 4          2024-10-05               102392                   8768
# 5          2024-10-08                51051                   4302
#
#    posti_occupati  posti_reali  tasso_occupazione
# 0           63351        48574               1.30
# 1           61263        46927               1.31
# 2           65518        49946               1.31
# 3           61836        46819               1.32
# 4          123760        93624               1.32
# 5           61266        46749               1.31

# %%
grouped_df.to_csv('../outputs/viz/historic_data.csv', index=False)

# %%
grouped_df.to_json('../outputs/viz/historic_data.json', orient='records', lines=True)
